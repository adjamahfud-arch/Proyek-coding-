# %% [markdown]
# <a href="https://colab.research.google.com/github/adjamahfud-arch/Proyek-coding-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#code formulir pendaftaran sederhana
nama = []
nilai = []
tinggi = []
umur = []
#sistem menentukan benar/tidak
def nama_nilai():
    for i in range(len(nama)):
        if (nilai[i] >= 75 and tinggi [i] >= 169) and umur[i] >=26:
            hasil = "lulus"
        else:
            hasil = "tidak lulus"
    print(f"{nama[i]} ~ {nilai[i]} ~ {tinggi[i]} ~ {umur[i]} ~ {hasil}")
#digunakan untuk mencetak data yang bernilai true
def lulus():
    for i in range(len(nama)):
        if (nilai[i] >= 75 and tinggi[i] >= 169) and umur[i] >= 26:
            print(nama[i])

pilih = "ya"
#sistem perulangan
while pilih == "ya":
      orang =input("masukan nama mu:")
      nama.append(orang)
      angka =int(input("masukan nilai mu:"))
      nilai.append(angka)
      angka2 =float(input("Masukan tinggi badan mu:"))
      tinggi.append(angka2)
      angka3 =int(input("masukan umur mu:"))
      umur.append(angka3)
      print("-" * 30)
      nama_nilai()
      print("-" * 30)
      pilih =input("salah ketik mau coba lagi? YA/TIDAK")
#hasil akhir
print("==hasil==")
uma =lulus()
print(uma)

print("terimakasih sudah mencoba program saya")
