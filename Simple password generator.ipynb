# %% [markdown]
# <a href="https://colab.research.google.com/github/adjamahfud-arch/Proyek-coding-/blob/main/Simple%20password%20generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user = []
#funcion jumlah minimal pasword
def total(password1):
    if len(password1) >= 8:
       return "data berhasil di simpan"
    else:
       return "pasword minimal 8 caracter"
#funcion verifikasi password
def angka(pasword, username1):
    for akun in user:
        if pasword == akun["pasword"] and username1 == akun["nama"]:
           return "login berhasil"
        else:
           return "pasword salah"

print("==program pasword==")

password1 =""
#perulangan pertama untuk memastikan password memenuhi syarat
while len(password1) < 8:
      username =input("masukan username:")
      password1 =input("masukan pasword:")
      if len(password1) >= 8:
          data = {
             "nama":username,
             "pasword": password1
}
          user.append(data)

      hasil =total(password1)
      print("-" * 30)
      print(hasil)
      print("-" * 30)

status ="gagal"
#perulangan ke dua untuk memverifikasi password benar
while status != "login berhasil":
      username1 =input("masukan username lagi:")
      pasword =input("masukan password lagi:")

      status =angka(pasword, username1)
      #hasil
      print("-" * 30)
      print(status)
      print("-" * 30)


print("terimakasih sudah mencoba program saya")
# Out:
#   File "<tokenize>", line 14
#     return "pasword salah"
#     ^
# IndentationError: unindent does not match any outer indentation level
